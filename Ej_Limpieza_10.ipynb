# %% [markdown]
# <a href="https://colab.research.google.com/github/OpheliaVlzqz/MineriaDatos/blob/main/Ej_Limpieza_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EJERCICIO DE LIMPIEZA DE DATOS
#
# EQUIPO 10
#
# Grupo:001 Lunes de 7-10 PM
#
# INTEGRANTES:
#
# 1856652 Velázquez Montemayor Ofelia
#
# 1862149 Cruz Martínez Diego Adrian
#
# 1867216 Martínez Reyes Jose Miguel
#
# 1941488 García Ortega Jose Andrés
#
# 1941564 Ramirez Moreno Diana Gabriela

# %% [markdown]
# Base de datos: Iris Species
# https://www.kaggle.com/uciml/iris

# %% [markdown]
# a)Importar librerias y bases de datos

# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv("/content/Iris.csv")

# %% [markdown]
# b)visualización de los datos

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# Hay 150 filas y 6 columnas

# %%
df.head(n=8)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa

# %%
df.tail(n=8)
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 142  143            5.8  ...           1.9  Iris-virginica
# 143  144            6.8  ...           2.3  Iris-virginica
# 144  145            6.7  ...           2.5  Iris-virginica
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [8 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# c)Descripción basica de columnas

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# Los datos de las columnas son en su mayoria flotantes a excepción de la primera y ultima que es enteros y objetos respectivamente

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]>

# %% [markdown]
# No hay celdas vacias

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# d)clasificación de los datos

# %%
df.PetalLengthCm.unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
setosa_df=df[df.Species=="Iris-setosa"]

# %%
setosa_df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
setosa_df.drop("Species",axis=1)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# 5    6            5.4           3.9            1.7           0.4
# 6    7            4.6           3.4            1.4           0.3
# 7    8            5.0           3.4            1.5           0.2
# 8    9            4.4           2.9            1.4           0.2
# 9   10            4.9           3.1            1.5           0.1
# 10  11            5.4           3.7            1.5           0.2
# 11  12            4.8           3.4            1.6           0.2
# 12  13            4.8           3.0            1.4           0.1
# ...

# %% [markdown]
# Agrupamos los datos de la planta de especie Iris-setosa

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
versicolor_df=df[df.Species=="Iris-versicolor"]

# %%
versicolor_df.drop("Species",axis=1)
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %% [markdown]
# Agrupamos los datos de la planta Iris-versicolor

# %%
virginica_df=df[df.Species=="Iris-virginica"]

# %%
virginica_df.drop("Species",axis=1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %% [markdown]
# Agrupamos los datos de la planta Iris-virginica

# %% [markdown]
# e)cambiar nombres de columnas

# %%
df.rename(columns={"Species":"Especies","PetalWidthCm":"AnchoPetalo","PetalLengthCm":"LargoPetalo","SepalWidthCm":"AnchoSepalo","SepalLengthCm":"LargoSepalo"})
# Out:
#       Id  LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo        Especies
# 0      1          5.1          3.5          1.4          0.2     Iris-setosa
# 1      2          4.9          3.0          1.4          0.2     Iris-setosa
# 2      3          4.7          3.2          1.3          0.2     Iris-setosa
# 3      4          4.6          3.1          1.5          0.2     Iris-setosa
# 4      5          5.0          3.6          1.4          0.2     Iris-setosa
# ..   ...          ...          ...          ...          ...             ...
# 145  146          6.7          3.0          5.2          2.3  Iris-virginica
# 146  147          6.3          2.5          5.0          1.9  Iris-virginica
# 147  148          6.5          3.0          5.2          2.0  Iris-virginica
# 148  149          6.2          3.4          5.4          2.3  Iris-virginica
# 149  150          5.9          3.0          5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# f)Guardar otros archivos con agrupaciones

# %%
setosa_df.to_csv("Setosa.csv",index=False)

# %%
virginica_df.to_csv("Virginica.csv",index=False)

# %%
versicolor_df.to_csv("Versicolor.csv",index=False)

# %% [markdown]
# g)Responder a las preguntas de interes

# %%
df_0=df.fillna(0)

# %% [markdown]
# Aqui rellenamos con 0 todas las columnas vacias

# %%
df_drop=df.dropna()

# %% [markdown]
# Eliminamos todas las filas que tengan datos nulos

# %%
df_drop_column = df.dropna(axis=1)

# %% [markdown]
# Eliminamos todas las columnas que tengan datos nulos

# %% [markdown]
# PUNTOS EXTRAS

# %% [markdown]
# comando df.dropna()
#
# Elimina los valores que faltan
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %% [markdown]
# comando df.astype()
#
# Convierte un objeto pandas en un dtype especificado.
#
# astype(dtype, copy=True, errors='raise')
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html

# %% [markdown]
# PROCESAMIENTO NO MENCIONADO EN LA PRACTICA

# %%
by_ancho=df.sort_values("PetalWidthCm")

# %%
by_ancho
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 32    33            5.2  ...           0.1     Iris-setosa
# 13    14            4.3  ...           0.1     Iris-setosa
# 37    38            4.9  ...           0.1     Iris-setosa
# 9     10            4.9  ...           0.1     Iris-setosa
# 12    13            4.8  ...           0.1     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 140  141            6.7  ...           2.4  Iris-virginica
# 114  115            5.8  ...           2.4  Iris-virginica
# 100  101            6.3  ...           2.5  Iris-virginica
# 144  145            6.7  ...           2.5  Iris-virginica
# 109  110            7.2  ...           2.5  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# https://www.analyticslane.com/2019/04/29/diferentes-formas-de-ordenar-dataframes-en-pandas/
#
# Link de referencia para el procesamiento extra
